# %%
import numpy as np
import pandas as pd

# %%
data = {
    "name": ["Ram", "Shyam", "Hari"],
    "age": [25, 30, 22],
    "score": [85, 90, 78]
}

# %%
# creating the dataframe
df = pd.DataFrame(data)
df
# Out:
#     name  age  score
# 0    Ram   25     85
# 1  Shyam   30     90
# 2   Hari   22     78

# %%
data = pd.read_csv("titanic.csv")
# yesle data lai save garxa 
data.to_csv("titanic_saved.csv")

# %%
# data ko structure herne kasari ta
# hami le data paye paxi we have to understand its structurea and summary statistics so yo gari halne
print(data.info())
print(data.shape)
print(data.head(10))
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# ...

# %%
print(data.columns)

# directly column haru access garne tarika
print(data[["Age","Fare", "Survived"]])

# rows and columns lai index bata access garne tarika
print(data.iloc[2:5, :5])

# %%
new_data = data[data["Age"] >60]
total_survived = data[data["Survived"] == 1].count()
print("total survived:", total_survived)
print(new_data[new_data["Survived"] == 1])
# Out:
# total survived: PassengerId    342
# Survived       342
# Pclass         342
# Name           342
# Sex            342
# Age            290
# SibSp          342
# Parch          342
# Ticket         342
# Fare           342
# Cabin          136
# Embarked       340
# dtype: int64

# %%
# print(data["Sex"])
new_data = data[(data["Age"] > 30)&(data["Sex"] == "female")&(data["Fare"] > 100)]
print(new_data)
