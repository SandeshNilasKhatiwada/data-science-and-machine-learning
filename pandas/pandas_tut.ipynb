# %%
import numpy as np
import pandas as pd

# %%
data = {
    "name": ["Ram", "Shyam", "Hari"],
    "age": [25, 30, 22],
    "score": [85, 90, 78]
}

# %%
# creating the dataframe
df = pd.DataFrame(data)
df
# Out:
#     name  age  score
# 0    Ram   25     85
# 1  Shyam   30     90
# 2   Hari   22     78
